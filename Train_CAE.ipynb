# %% [markdown]
# ***Import library***

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.nn as nn

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ***Hyper Parameters***

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

batch_size = 8
learning_rate = 0.001
num_epochs = 800

normal_dir = 'C:\\Users\\WorkStation\\Desktop\\캡디이미지\\CAE_dataset\\normal'
abnormal_dir = 'C:\\Users\\WorkStation\\Desktop\\캡디이미지\\CAE_dataset\\abnormal'

# %% [markdown]
# ***Load Datasets***

# %%
normal_set = datasets.ImageFolder(
    normal_dir,
    transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])
)

abnormal_set = datasets.ImageFolder(
    abnormal_dir,
    transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])
)

train_set, test_set = torch.utils.data.random_split(normal_set, [len(normal_set) - 80, 80])

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,shuffle=True)
normal_loader = torch.utils.data.DataLoader(normal_set, batch_size=batch_size, shuffle=True)
abnormal_loader = torch.utils.data.DataLoader(abnormal_set, batch_size=batch_size,shuffle=True)

print(f"Number of normal data : {len(normal_set)}")
print(f"Number of abnormal data : {len(abnormal_set)}")
# Out:
# Number of normal data : 296
# Number of abnormal data : 2100

# %%
images, labels = next(iter(train_loader))

fig = plt.figure(figsize=(15,3))
for i, img, label in zip(range(batch_size), images, labels):
    numpy_img = np.transpose(img.numpy(), (1, 2, 0))
    ax = fig.add_subplot(1, batch_size, i+1)
    ax.imshow(numpy_img)
plt.show()

# %% [markdown]
# **AutoEncoder**

# %%
class ConvAutoEncoder(nn.Module):
    def __init__(self):
        super(ConvAutoEncoder, self).__init__()
        
        # Encoder
        self.cnn_layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2))

        self.cnn_layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2))
        
        self.cnn_layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2))

        # Decoder        
        self.tran_cnn_layer1 = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size = 2, stride = 2, padding=0),
            nn.ReLU())
        
        self.tran_cnn_layer2 = nn.Sequential(
            nn.ConvTranspose2d(32, 16, kernel_size = 2, stride = 2, padding=0),
            nn.ReLU())

        self.tran_cnn_layer3 = nn.Sequential(
            nn.ConvTranspose2d(16, 3, kernel_size = 2, stride = 2, padding=0),
            nn.Sigmoid())
            
            
    def forward(self, x):
        output = self.cnn_layer1(x)
        output = self.cnn_layer2(output)
        output = self.cnn_layer3(output)        
        output = self.tran_cnn_layer1(output)
        output = self.tran_cnn_layer2(output)
        output = self.tran_cnn_layer3(output)
        
        return output
    
model = ConvAutoEncoder()
model.to(device)
# Out:
# ConvAutoEncoder(
#   (cnn_layer1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_layer2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_layer3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (tran_cnn_layer1): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU()
#   )
#   (tran_cnn_layer2): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU()
#   )
#   (tran_cnn_layer3): Sequential(
#     (0): ConvTranspose2d(16, 3, kernel_size=(2, 2), stride=(2, 2))
#     (1): Sigmoid()
#   )
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ***Train & Test***

# %%
BEST_MODEL_PATH = "CAE_best_model.pth"

best_loss = 1.0
train_losses = []
test_losses = []


for epoch in range(num_epochs):
    
    ########### Train ###########
    train_loss = 0
    for i, (X_train, _) in enumerate(train_loader):
        X_train = X_train.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(X_train)
        loss = criterion(outputs, X_train)
        train_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
    train_losses.append(train_loss / len(train_loader))
       
    
    ########### Test ###########  
    with torch.no_grad():
        test_loss = 0
        for i, (X_test, _) in enumerate(test_loader):
            X_test = X_test.to(device)
            
            outputs = model(X_test)
            loss = criterion(outputs, X_test)
            test_loss += loss.item()   
            
        test_losses.append(test_loss / len(test_loader))
        
    if epoch % 10 == 0:
        print(f'Epoch: {epoch}/{num_epochs}',
              'Train loss: {:.5f}..'.format(train_loss / len(train_loader) * batch_size), 
              'Test loss: {:.5f}..'.format(test_loss / len(test_loader) * batch_size))
                
########### Save Model ###########
torch.save(model.state_dict(), BEST_MODEL_PATH)
# Out:
# Epoch: 0/800 Train loss: 0.36439.. Test loss: 0.24217..
# Epoch: 10/800 Train loss: 0.02310.. Test loss: 0.02222..
# Epoch: 20/800 Train loss: 0.01603.. Test loss: 0.01588..
# Epoch: 30/800 Train loss: 0.01340.. Test loss: 0.01330..
# Epoch: 40/800 Train loss: 0.01202.. Test loss: 0.01206..
# Epoch: 50/800 Train loss: 0.01145.. Test loss: 0.01148..
# Epoch: 60/800 Train loss: 0.01108.. Test loss: 0.01112..
# Epoch: 70/800 Train loss: 0.01076.. Test loss: 0.01080..
# Epoch: 80/800 Train loss: 0.01047.. Test loss: 0.01052..
# Epoch: 90/800 Train loss: 0.01021.. Test loss: 0.01024..
# Epoch: 100/800 Train loss: 0.00956.. Test loss: 0.00952..
# Epoch: 110/800 Train loss: 0.00918.. Test loss: 0.00920..
# Epoch: 120/800 Train loss: 0.00900.. Test loss: 0.00904..
# Epoch: 130/800 Train loss: 0.00886.. Test loss: 0.00888..
# Epoch: 140/800 Train loss: 0.00874.. Test loss: 0.00877..
# Epoch: 150/800 Train loss: 0.00864.. Test loss: 0.00867..
# Epoch: 160/800 Train loss: 0.00855.. Test loss: 0.00858..
# Epoch: 170/800 Train loss: 0.00846.. Test loss: 0.00852..
# Epoch: 180/800 Train loss: 0.00839.. Test loss: 0.00847..
# Epoch: 190/800 Train loss: 0.00832.. Test loss: 0.00840..
# Epoch: 200/800 Train loss: 0.00826.. Test loss: 0.00833..
# Epoch: 210/800 Train loss: 0.00820.. Test loss: 0.00828..
# Epoch: 220/800 Train loss: 0.00816.. Test loss: 0.00823..
# Epoch: 230/800 Train loss: 0.00810.. Test loss: 0.00817..
# Epoch: 240/800 Train loss: 0.00808.. Test loss: 0.00816..
# Epoch: 250/800 Train loss: 0.00806.. Test loss: 0.00841..
# Epoch: 260/800 Train loss: 0.00802.. Test loss: 0.00812..
# Epoch: 270/800 Train loss: 0.00795.. Test loss: 0.00802..
# Epoch: 280/800 Train loss: 0.00792.. Test loss: 0.00799..
# Epoch: 290/800 Train loss: 0.00795.. Test loss: 0.00799..
# Epoch: 300/800 Train loss: 0.00800.. Test loss: 0.00796..
# Epoch: 310/800 Train loss: 0.00784.. Test loss: 0.00790..
# Epoch: 320/800 Train loss: 0.00781.. Test loss: 0.00789..
# Epoch: 330/800 Train loss: 0.00780.. Test loss: 0.00792..
# Epoch: 340/800 Train loss: 0.00780.. Test loss: 0.00784..
# Epoch: 350/800 Train loss: 0.00777.. Test loss: 0.00790..
# Epoch: 360/800 Train loss: 0.00775.. Test loss: 0.00788..
# Epoch: 370/800 Train loss: 0.00768.. Test loss: 0.00777..
# Epoch: 380/800 Train loss: 0.00768.. Test loss: 0.00781..
# Epoch: 390/800 Train loss: 0.00768.. Test loss: 0.00775..
# Epoch: 400/800 Train loss: 0.00770.. Test loss: 0.00779..
# Epoch: 410/800 Train loss: 0.00762.. Test loss: 0.00774..
# Epoch: 420/800 Train loss: 0.00763.. Test loss: 0.00774..
# Epoch: 430/800 Train loss: 0.00775.. Test loss: 0.00780..
# Epoch: 440/800 Train loss: 0.00765.. Test loss: 0.00772..
# Epoch: 450/800 Train loss: 0.00758.. Test loss: 0.00765..
# Epoch: 460/800 Train loss: 0.00760.. Test loss: 0.00773..
# Epoch: 470/800 Train loss: 0.00753.. Test loss: 0.00764..
# Epoch: 480/800 Train loss: 0.00756.. Test loss: 0.00766..
# Epoch: 490/800 Train loss: 0.00755.. Test loss: 0.00764..
# Epoch: 500/800 Train loss: 0.00752.. Test loss: 0.00761..
# Epoch: 510/800 Train loss: 0.00749.. Test loss: 0.00764..
# Epoch: 520/800 Train loss: 0.00748.. Test loss: 0.00762..
# Epoch: 530/800 Train loss: 0.00747.. Test loss: 0.00759..
# Epoch: 540/800 Train loss: 0.00753.. Test loss: 0.00757..
# Epoch: 550/800 Train loss: 0.00746.. Test loss: 0.00757..
# Epoch: 560/800 Train loss: 0.00745.. Test loss: 0.00757..
# Epoch: 570/800 Train loss: 0.00744.. Test loss: 0.00753..
# Epoch: 580/800 Train loss: 0.00764.. Test loss: 0.00754..
# Epoch: 590/800 Train loss: 0.00741.. Test loss: 0.00756..
# Epoch: 600/800 Train loss: 0.00750.. Test loss: 0.00751..
# Epoch: 610/800 Train loss: 0.00740.. Test loss: 0.00750..
# Epoch: 620/800 Train loss: 0.00741.. Test loss: 0.00753..
# Epoch: 630/800 Train loss: 0.00737.. Test loss: 0.00748..
# Epoch: 640/800 Train loss: 0.00739.. Test loss: 0.00750..
# Epoch: 650/800 Train loss: 0.00737.. Test loss: 0.00748..
# Epoch: 660/800 Train loss: 0.00738.. Test loss: 0.00757..
# Epoch: 670/800 Train loss: 0.00738.. Test loss: 0.00748..
# Epoch: 680/800 Train loss: 0.00737.. Test loss: 0.00748..
# Epoch: 690/800 Train loss: 0.00737.. Test loss: 0.00748..
# Epoch: 700/800 Train loss: 0.00737.. Test loss: 0.00747..
# Epoch: 710/800 Train loss: 0.00734.. Test loss: 0.00745..
# Epoch: 720/800 Train loss: 0.00735.. Test loss: 0.00747..
# Epoch: 730/800 Train loss: 0.00744.. Test loss: 0.00743..
# Epoch: 740/800 Train loss: 0.00747.. Test loss: 0.00752..
# Epoch: 750/800 Train loss: 0.00732.. Test loss: 0.00742..
# Epoch: 760/800 Train loss: 0.00732.. Test loss: 0.00740..
# Epoch: 770/800 Train loss: 0.00730.. Test loss: 0.00739..
# Epoch: 780/800 Train loss: 0.00729.. Test loss: 0.00737..
# Epoch: 790/800 Train loss: 0.00731.. Test loss: 0.00740..

# %% [markdown]
# ***Losses of normal & abnormal data***

# %%
model.eval()

normal_loss = 0
normal_losses = []

abnormal_loss = 0
abnormal_losses = []

for i, (normal_img, _) in enumerate(normal_loader):
    normal_img = normal_img.to(device)
    
    normal_outputs = model(normal_img)
    loss = criterion(normal_outputs, normal_img)
    #normal_loss = loss.item()
    normal_losses.append(loss.item())
    
    print(f'Normal loss: {loss.item()}')
    
for i, (abnormal_img, _) in enumerate(abnormal_loader):   
    abnormal_img = abnormal_img.to(device)
    
    abnormal_outputs = model(abnormal_img)
    loss = criterion(abnormal_outputs,abnormal_img)
    abnormal_losses.append(loss.item())
    
    print(f'Abnormal loss: {loss.item()}')
# Out:
# Normal loss: 0.0008653324912302196
# Normal loss: 0.0009296932839788496
# Normal loss: 0.0009271523449569941
# Normal loss: 0.0009267820860259235
# Normal loss: 0.00083258276572451
# Normal loss: 0.0008502301061525941
# Normal loss: 0.0008757250034250319
# Normal loss: 0.0009273636969737709
# Normal loss: 0.0009404232259839773
# Normal loss: 0.0008873828919604421
# Normal loss: 0.0009471101802773774
# Normal loss: 0.0009691152372397482
# Normal loss: 0.0009632873698137701
# Normal loss: 0.0009081742609851062
# Normal loss: 0.0009068595245480537
# Normal loss: 0.00093807652592659
# Normal loss: 0.0009304634295403957
# Normal loss: 0.0008806355181150138
# Normal loss: 0.0009209365234710276
# Normal loss: 0.0009735999046824872
# Normal loss: 0.0008839248912408948
# Normal loss: 0.0009200682397931814
# Normal loss: 0.0009130361140705645
# Normal loss: 0.0009538575541228056
# Normal loss: 0.0009778478415682912
# Normal loss: 0.0008886410505510867
# Normal loss: 0.0009078713483177125
# Normal loss: 0.0009144483483396471
# Normal loss: 0.0009000116842798889
# Normal loss: 0.000949798384681344
# Normal loss: 0.000928386696614325
# Normal loss: 0.0009097785223275423
# Normal loss: 0.0009514387347735465
# Normal loss: 0.0009198998450301588
# Normal loss: 0.0009485420305281878
# Normal loss: 0.000897543563041836
# Normal loss: 0.0009466682095080614
# Abnormal loss: 0.0034427440259605646
# Abnormal loss: 0.0030243289656937122
# Abnormal loss: 0.003865641774609685
# Abnormal loss: 0.0037811852525919676
# Abnormal loss: 0.004376290366053581
# Abnormal loss: 0.004594018682837486
# Abnormal loss: 0.004337357822805643
# Abnormal loss: 0.0034329986665397882
# Abnormal loss: 0.004291140008717775
# Abnormal loss: 0.002780772279947996
# Abnormal loss: 0.0034753878135234118
# Abnormal loss: 0.003881181590259075
# Abnormal loss: 0.0038852677680552006
# Abnormal loss: 0.0038080255035310984
# Abnormal loss: 0.0031761133577674627
# Abnormal loss: 0.004333559889346361
# Abnormal loss: 0.004265931900590658
# Abnormal loss: 0.004105697385966778
# Abnormal loss: 0.002839237917214632
# Abnormal loss: 0.0029944826383143663
# Abnormal loss: 0.003656429471448064
# Abnormal loss: 0.0039441767148673534
# Abnormal loss: 0.0034490523394197226
# Abnormal loss: 0.0034468984231352806
# Abnormal loss: 0.004382999148219824
# Abnormal loss: 0.003614877350628376
# Abnormal loss: 0.003963417373597622
# Abnormal loss: 0.004490539897233248
# Abnormal loss: 0.003744758665561676
# Abnormal loss: 0.003478562692180276
# Abnormal loss: 0.0043112244457006454
# Abnormal loss: 0.0038699964061379433
# Abnormal loss: 0.0034184434916824102
# Abnormal loss: 0.004422281868755817
# Abnormal loss: 0.0035945517010986805
# Abnormal loss: 0.0031971249263733625
# Abnormal loss: 0.0036295554600656033
# Abnormal loss: 0.0031543343793600798
# Abnormal loss: 0.003547276370227337
# Abnormal loss: 0.0046399738639593124
# Abnormal loss: 0.003524693427607417
# Abnormal loss: 0.003697649808600545
# Abnormal loss: 0.0022109700366854668
# Abnormal loss: 0.003867202904075384
# Abnormal loss: 0.0033368049189448357
# Abnormal loss: 0.0042465729638934135
# Abnormal loss: 0.004871954210102558
# Abnormal loss: 0.0033859945833683014
# Abnormal loss: 0.0032291889656335115
# Abnormal loss: 0.0035670308861881495
# Abnormal loss: 0.002811022335663438
# Abnormal loss: 0.0034023867920041084
# Abnormal loss: 0.0027557676658034325
# Abnormal loss: 0.003980210982263088
# Abnormal loss: 0.0034550337586551905
# Abnormal loss: 0.003447154304012656
# Abnormal loss: 0.003643675707280636
# Abnormal loss: 0.004322226159274578
# Abnormal loss: 0.0036834084894508123
# Abnormal loss: 0.0037178583443164825
# Abnormal loss: 0.004481027834117413
# Abnormal loss: 0.0030844619031995535
# Abnormal loss: 0.0038166751619428396
# Abnormal loss: 0.004282522480934858
# Abnormal loss: 0.003081136615946889
# Abnormal loss: 0.004555186722427607
# Abnormal loss: 0.0039113773964345455
# Abnormal loss: 0.004087948240339756
# Abnormal loss: 0.004260851535946131
# Abnormal loss: 0.004102794453501701
# Abnormal loss: 0.003938848618417978
# Abnormal loss: 0.0040115127339959145
# Abnormal loss: 0.004231287632137537
# Abnormal loss: 0.004564455710351467
# Abnormal loss: 0.004728035535663366
# Abnormal loss: 0.0037415027618408203
# Abnormal loss: 0.0036896627862006426
# Abnormal loss: 0.004313507582992315
# Abnormal loss: 0.004129393026232719
# Abnormal loss: 0.003099537454545498
# Abnormal loss: 0.004046203568577766
# Abnormal loss: 0.004193513188511133
# Abnormal loss: 0.00252515752799809
# Abnormal loss: 0.005098775494843721
# Abnormal loss: 0.004423584323376417
# Abnormal loss: 0.004259190522134304
# Abnormal loss: 0.004452157765626907
# Abnormal loss: 0.00447393674403429
# Abnormal loss: 0.0035930583253502846
# Abnormal loss: 0.003467148169875145
# Abnormal loss: 0.004204101860523224
# Abnormal loss: 0.004427484702318907
# Abnormal loss: 0.0033050610218197107
# Abnormal loss: 0.004517793655395508
# Abnormal loss: 0.003460636595264077
# Abnormal loss: 0.004342593252658844
# Abnormal loss: 0.0038981176912784576
# Abnormal loss: 0.004620082210749388
# Abnormal loss: 0.0032836671452969313
# Abnormal loss: 0.0041233547963202
# Abnormal loss: 0.004241006448864937
# Abnormal loss: 0.003985726740211248
# Abnormal loss: 0.004976166877895594
# Abnormal loss: 0.004288203548640013
# Abnormal loss: 0.004632196389138699
# Abnormal loss: 0.0035304175689816475
# Abnormal loss: 0.0036117075942456722
# Abnormal loss: 0.0035138437524437904
# Abnormal loss: 0.004337423015385866
# Abnormal loss: 0.0028075631707906723
# Abnormal loss: 0.0033164185006171465
# Abnormal loss: 0.0036336693447083235
# Abnormal loss: 0.0036348095163702965
# Abnormal loss: 0.0037774040829390287
# Abnormal loss: 0.0037151379510760307
# Abnormal loss: 0.004492477979511023
# Abnormal loss: 0.004392984788864851
# Abnormal loss: 0.0039934804663062096
# Abnormal loss: 0.003714559832587838
# Abnormal loss: 0.003157218685373664
# Abnormal loss: 0.0038939567748457193
# Abnormal loss: 0.003891810541972518
# Abnormal loss: 0.0023008522111922503
# Abnormal loss: 0.004807521589100361
# Abnormal loss: 0.003954793326556683
# Abnormal loss: 0.0034758751280605793
# Abnormal loss: 0.004313487559556961
# Abnormal loss: 0.0030879350379109383
# Abnormal loss: 0.004295730963349342
# Abnormal loss: 0.003946502692997456
# Abnormal loss: 0.004596400540322065
# Abnormal loss: 0.0036266993265599012
# Abnormal loss: 0.004029156640172005
# Abnormal loss: 0.0032984844874590635
# Abnormal loss: 0.004293367266654968
# Abnormal loss: 0.004247496370226145
# Abnormal loss: 0.0037565359380096197
# Abnormal loss: 0.003554690396413207
# Abnormal loss: 0.004442350007593632
# Abnormal loss: 0.0037487412337213755
# Abnormal loss: 0.0033955411054193974
# Abnormal loss: 0.004035925958305597
# Abnormal loss: 0.003401240101084113
# Abnormal loss: 0.003229551948606968
# Abnormal loss: 0.004863128997385502
# Abnormal loss: 0.003048210171982646
# Abnormal loss: 0.0036200673785060644
# Abnormal loss: 0.0036667431704699993
# Abnormal loss: 0.003649849910289049
# Abnormal loss: 0.0029878460336476564
# Abnormal loss: 0.0034943355713039637
# Abnormal loss: 0.0036888266913592815
# Abnormal loss: 0.003246244275942445
# Abnormal loss: 0.003614225657656789
# Abnormal loss: 0.004371294751763344
# Abnormal loss: 0.0043393089435994625
# Abnormal loss: 0.003874599002301693
# Abnormal loss: 0.0028271805495023727
# Abnormal loss: 0.003612246597185731
# Abnormal loss: 0.0032712784595787525
# Abnormal loss: 0.003760478924959898
# Abnormal loss: 0.0047768400982022285
# Abnormal loss: 0.003960418980568647
# Abnormal loss: 0.004046300426125526
# Abnormal loss: 0.0033283322118222713
# Abnormal loss: 0.0030390655156224966
# Abnormal loss: 0.003998501691967249
# Abnormal loss: 0.0030782180838286877
# Abnormal loss: 0.003305784659460187
# Abnormal loss: 0.004464554134756327
# Abnormal loss: 0.003545108949765563
# Abnormal loss: 0.003520780708640814
# Abnormal loss: 0.0032311230897903442
# Abnormal loss: 0.00300487014465034
# Abnormal loss: 0.0037965518422424793
# Abnormal loss: 0.003909665159881115
# Abnormal loss: 0.003581118769943714
# Abnormal loss: 0.0031244049314409494
# Abnormal loss: 0.0032689988147467375
# Abnormal loss: 0.0037580695934593678
# Abnormal loss: 0.0031975300516933203
# Abnormal loss: 0.003609288716688752
# Abnormal loss: 0.004043477587401867
# Abnormal loss: 0.0033889631740748882
# Abnormal loss: 0.0033452920615673065
# Abnormal loss: 0.0036523828748613596
# Abnormal loss: 0.004099451471120119
# Abnormal loss: 0.0045797331258654594
# Abnormal loss: 0.003515885677188635
# Abnormal loss: 0.004563132766634226
# Abnormal loss: 0.003315805923193693
# Abnormal loss: 0.0034583262167871
# Abnormal loss: 0.003908965736627579
# Abnormal loss: 0.0034178670030087233
# Abnormal loss: 0.0033537731505930424
# Abnormal loss: 0.0033556241542100906
# Abnormal loss: 0.0039577484130859375
# Abnormal loss: 0.0037417784333229065
# Abnormal loss: 0.003242986975237727
# Abnormal loss: 0.0034435661509633064
# Abnormal loss: 0.004194865934550762
# Abnormal loss: 0.003490195609629154
# Abnormal loss: 0.00433371402323246
# Abnormal loss: 0.004054591525346041
# Abnormal loss: 0.004758425056934357
# Abnormal loss: 0.00363233988173306
# Abnormal loss: 0.003923212643712759
# Abnormal loss: 0.0036756894551217556
# Abnormal loss: 0.0038243455346673727
# Abnormal loss: 0.003572117304429412
# Abnormal loss: 0.004440310876816511
# Abnormal loss: 0.003848819062113762
# Abnormal loss: 0.004439502954483032
# Abnormal loss: 0.004451326094567776
# Abnormal loss: 0.0032020912040024996
# Abnormal loss: 0.004864185582846403
# Abnormal loss: 0.0024398232344537973
# Abnormal loss: 0.0038820647168904543
# Abnormal loss: 0.00449163094162941
# Abnormal loss: 0.004045921843498945
# Abnormal loss: 0.003285540034994483
# Abnormal loss: 0.004267471842467785
# Abnormal loss: 0.0038890887517482042
# Abnormal loss: 0.005177682731300592
# Abnormal loss: 0.003272830508649349
# Abnormal loss: 0.003539625322446227
# Abnormal loss: 0.004308614879846573
# Abnormal loss: 0.004436101298779249
# Abnormal loss: 0.003715012688189745
# Abnormal loss: 0.0043685599230229855
# Abnormal loss: 0.004005369730293751
# Abnormal loss: 0.002400849247351289
# Abnormal loss: 0.0036124654579907656
# Abnormal loss: 0.003067729761824012
# Abnormal loss: 0.0038613209035247564
# Abnormal loss: 0.004478730261325836
# Abnormal loss: 0.0034016557037830353
# Abnormal loss: 0.0038976185023784637
# Abnormal loss: 0.0048899040557444096
# Abnormal loss: 0.003820178797468543
# Abnormal loss: 0.004965075757354498
# Abnormal loss: 0.002604864537715912
# Abnormal loss: 0.0036059196572750807
# Abnormal loss: 0.0029694847762584686
# Abnormal loss: 0.003778334241360426
# Abnormal loss: 0.0035715685226023197
# Abnormal loss: 0.0038287986535578966
# Abnormal loss: 0.004003582522273064
# Abnormal loss: 0.003789409762248397
# Abnormal loss: 0.003896100213751197
# Abnormal loss: 0.004722024314105511
# Abnormal loss: 0.004477750509977341
# Abnormal loss: 0.003344283439218998
# Abnormal loss: 0.003619144903495908
# Abnormal loss: 0.004189780913293362
# Abnormal loss: 0.003126173047348857
# Abnormal loss: 0.004952195566147566
# Abnormal loss: 0.003792928997427225
# Abnormal loss: 0.004464618396013975
# Abnormal loss: 0.003992888145148754
# Abnormal loss: 0.0033867936581373215
# Abnormal loss: 0.00444128317758441
# Abnormal loss: 0.003184164874255657

# %% [markdown]
# ***Graph***

# %%
plt.figure(1)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(train_losses, label = 'train')
plt.plot(test_losses, label = 'test')
plt.legend()
plt.show()

plt.figure(2)
plt.xlabel('Number of Image')
plt.ylabel('loss')
plt.plot(normal_losses, label = 'normal')
plt.plot(abnormal_losses[:len(normal_loader)], label = 'abnormal')
plt.legend()
plt.show()

# %% [markdown]
# ***Result***

# %%
abnormal_images, abnormal_labels = next(iter(abnormal_loader))

fig = plt.figure(figsize=(15,3))

for i, img, label in zip(range(batch_size), abnormal_images, abnormal_labels):
    numpy_img = np.transpose(img.detach().numpy(), (1, 2, 0))
    ax = fig.add_subplot(1, batch_size, i+1)
    ax.imshow(numpy_img)
plt.show()

# %%
model.cpu()
abnormal_output = model(abnormal_images)

fig = plt.figure(figsize=(15,3))
for i, img, label in zip(range(batch_size), abnormal_output, abnormal_labels):
    loss = criterion(img, abnormal_images)
    print(loss.item())
    
    numpy_img = np.transpose(img.detach().numpy(), (1, 2, 0))
    ax = fig.add_subplot(1, batch_size, i+1)
    ax.imshow(numpy_img)
plt.show()
# Out:
# C:\Users\WorkStation\anaconda3\lib\site-packages\torch\nn\modules\loss.py:528: UserWarning: Using a target size (torch.Size([8, 3, 224, 224])) that is different to the input size (torch.Size([3, 224, 224])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# 0.011984352953732014
# 0.008501927368342876
# 0.010231751948595047
# 0.012271760031580925
# 0.010115875862538815
# 0.008341529406607151
# 0.01619362272322178
# 0.008427407592535019
